# %% [markdown]
# # Overview
#
# In 2000, Enron was one of the largest companies in the United States. By 2002, it had collapsed into bankruptcy due to widespread corporate fraud. In the resulting Federal investigation, a significant amount of typically confidential information entered into the public record, including tens of thousands of emails and detailed financial data for top executives.
#
# The goal of this project is to build a person of interest (POI, which means an individual who was indicted, reached a settlement or plea deal with the government, or testified in exchange for prosecution immunity) identifier based on financial and email data made public as a result of the Enron scandal. Machine learning is an excellent tool for this kind of classification task as it can use patterns discovered from labeled data to infer the classes of new observations.
#
# This dataset combines the public record of Enron emails and financial data with a hand-generated list of POI’s in the fraud case.

# %%
import os
import re
import scipy
import multiprocessing
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import xgboost
from sklearn import metrics
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import SelectPercentile
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

# %matplotlib inline

# %%
def split(data):
    feature = data.copy()
    label = feature.pop("poi").astype(int)
    return feature, label

# %%
df = pd.read_csv("train_data.csv")
features, labels = split(df)

# %%
print("# of features: {}".format(features.shape[1]))
print("# of samples: {}".format(features.shape[0]))
features.head()
# Out:
# # of features: 21
# # of samples: 113
#                    name      bonus  deferral_payments  deferred_income  \
# 0        RICE KENNETH D  1750000.0                NaN       -3504386.0
# 1    SKILLING JEFFREY K  5600000.0                NaN              NaN
# 2            SHELBY REX   200000.0                NaN          -4167.0
# 3      KOPPER MICHAEL J   800000.0                NaN              NaN
# 4  CALGER CHRISTOPHER F  1250000.0                NaN        -262500.0
#
#    director_fees                 email_address  exercised_stock_options  \
# 0            NaN            ken.rice@enron.com               19794175.0
# 1            NaN       jeff.skilling@enron.com               19250000.0
# 2            NaN          rex.shelby@enron.com                1624396.0
# 3            NaN      michael.kopper@enron.com                      NaN
# 4            NaN  christopher.calger@enron.com                      NaN
#
# ...

# %% [markdown]
# # Features Description
#
# ## Financial Features
#
# ### Salary Features
# * `salary`: Reflects items such as base salary, executive cash allowances, and benefits payments.
# * `bonus`: Reflects annual cash incentives paid based upon company performance. Also may include other retention payments.
# * `long_term_incentive`: Reflects long-term incentive cash payments from various long-term incentive programs designed to tie executive compensation to long-term success as measured against key performance drivers and business objectives over a multi-year period, generally 3 to 5 years.
# * `deferred_income`: Reflects voluntary executive deferrals of salary, annual cash incentives, and long-term cash incentives as well as cash fees deferred by non-employee directors under a deferred compensation arrangement. May also reflect deferrals under a stock option or phantom stock unit in lieu of cash arrangement.
# * `deferral_payments`: Reflects distributions from a deferred compensation arrangement due to termination of employment or due to in-service withdrawals as per plan provisions.
# * `loan_advances`: Reflects total amount of loan advances, excluding repayments, provided by the Debtor in return for a promise of repayment. In certain instances, the terms of the promissory notes allow for the option to repay with stock of the company.
# * `other`: Reflects items such as payments for severance, consulting services, relocation costs, tax advances and allowances for employees on international assignment (i.e. housing allowances, cost of living allowances, payments under Enron’s Tax Equalization Program, etc.). May also include payments provided with respect to employment agreements, as well as imputed income amounts for such things as use of corporate aircraft.
# * `expenses`: Reflects reimbursements of business expenses. May include fees paid for consulting services.
# * `director_fees`: Reflects cash payments and/or value of stock grants made in lieu of cash payments to non-employee directors.
# * `total_payments`: Sum of the above values.
#
# ### Stock Features
#
# * `restricted_stock_deferred`: Reflects value of restricted stock voluntarily deferred prior to release under a deferred compensation arrangement.
# * `exercised_stock_options`: Reflects amounts from exercised stock options which equal the market value in excess of the exercise price on the date the options were exercised either through cashless (same-day sale), stock swap or cash exercises. The reflected gain may differ from that realized by the insider due to fluctuations in the market price and the timing of any subsequent sale of the securities.
# * `restricted_stock`: Reflects the gross fair market value of shares and accrued dividends (and/or phantom units and dividend equivalents) on the date of release due to lapse of vesting periods, regardless of whether deferred.
# * `total_stock_value`: Sum of the above values.
#
#
# ## Email Features
# * `to_messages`: Total number of emails received (person’s inbox).
# * `email_address`: Email address of the person.
# * `from_poi_to_this_person`: Number of emails received by POIs.
# * `from_messages`: Total number of emails sent by this person.
# * `from_this_person_to_poi`: Number of emails sent by this person to a POI.
# * `shared_receipt_with_poi`: Number of emails addressed by someone else to a POI where this person was CC.

# %%
plt.figure(figsize=(15, 4))
sns.countplot(labels)
plt.grid(axis="y")
plt.show()

# %%
# Getting slight information about the dataframe
print("There are total of {} people in the dataset".format(len(df.index)))
print("Out of which {} are POI".format(df['poi'].value_counts()[True]))
# Out:
# There are total of 113 people in the dataset
# Out of which 13 are POI

# %%
df.describe().transpose()
# Out:
#                            count          mean           std        min  \
# bonus                       61.0  1.147436e+06  1.505189e+06    70000.0
# deferral_payments           28.0  6.344374e+05  8.603646e+05  -102500.0
# deferred_income             34.0 -4.625664e+05  8.095392e+05 -3504386.0
# director_fees               13.0  8.939785e+04  4.114339e+04     3285.0
# exercised_stock_options     81.0  2.985081e+06  6.004174e+06     3285.0
# expenses                    73.0  5.104055e+04  4.759668e+04      148.0
# from_messages               65.0  7.113231e+02  2.074498e+03       12.0
# from_poi_to_this_person     65.0  6.480000e+01  9.186321e+01        0.0
# from_this_person_to_poi     65.0  4.009231e+01  8.890141e+01        0.0
# loan_advances                2.0  4.096250e+07  5.736404e+07   400000.0
# long_term_incentive         49.0  7.926171e+05  9.504645e+05    71023.0
# other                       69.0  4.471774e+05  1.341564e+06        2.0
# ...

# %% [markdown]
# There are 113 observations and 22 variables in our dataset - 6 email features, 14 financial features, 1 name feature, and 1 POI label, and they are divided between 13 POI’s and 100 non-POI’s.

# %% [markdown]
# # Missing Values

# %% [markdown]
# There are lots of missing values in this dataset.

# %%
for column in features.columns:
    features[column] = features[column].apply(lambda x: np.NaN if x == 'NaN' else x)

# %%
def na_check(df_data):
    data_na = (df_data.isnull().sum() / len(df_data)) * 100
    data_na = data_na.drop(data_na[data_na == 0].index).sort_values(ascending=False)
    missing_data = pd.DataFrame({'Missing Ratio' :data_na})
    display(missing_data.style.background_gradient(cmap='Blues'))
na_check(features)
# Out:
# <style  type="text/css" >
#     #T_69aac934_b638_11ea_81ab_34e12df959fbrow0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_69aac934_b638_11ea_81ab_34e12df959fbrow1_col0 {
#             background-color:  #08468b;
#             color:  #f1f1f1;
#         }    #T_69aac934_b638_11ea_81ab_34e12df959fbrow2_col0 {
#             background-color:  #084e98;
#             color:  #f1f1f1;
#         }    #T_69aac934_b638_11ea_81ab_34e12df959fbrow3_col0 {
#             background-color:  #2676b8;
#             color:  #000000;
#         }    #T_69aac934_b638_11ea_81ab_34e12df959fbrow4_col0 {
#             background-color:  #3787c0;
#             color:  #000000;
#         }    #T_69aac934_b638_11ea_81ab_34e12df959fbrow5_col0 {
#             background-color:  #68acd5;
#             color:  #000000;
#         }    #T_69aac934_b638_11ea_81ab_34e12df959fbrow6_col0 {
#             background-color:  #9ac8e0;
#             color:  #000000;
# ...

# %%
plt.figure(figsize=(15, 6))
sns.heatmap(features.isnull(), cbar=True, cmap="Blues")
plt.show()

# %% [markdown]
# "LOCKHART EUGENE E" has all the values missing and will be removed

# %%
display(features[features.name == "LOCKHART EUGENE E"])
features = features.drop(index=107, axis=0)
# Out:
#                   name  bonus  deferral_payments  deferred_income  \
# 107  LOCKHART EUGENE E    NaN                NaN              NaN
#
#      director_fees email_address  exercised_stock_options  expenses  \
# 107            NaN           NaN                      NaN       NaN
#
#      from_messages  from_poi_to_this_person  ...  loan_advances  \
# 107            NaN                      NaN  ...            NaN
#
#      long_term_incentive  other  restricted_stock  restricted_stock_deferred  \
# 107                  NaN    NaN               NaN                        NaN
#
#      salary  shared_receipt_with_poi  to_messages  total_payments  \
# 107     NaN                      NaN          NaN             NaN
#
#      total_stock_value
# 107                NaN
#
# [1 rows x 21 columns]

# %% [markdown]
# # Numerical Feature

# %%
financial_features = ['salary', 'deferral_payments', 'total_payments', 'loan_advances', 
                      'bonus', 'restricted_stock_deferred', 'deferred_income', 'total_stock_value', 
                      'expenses', 'exercised_stock_options', 'other', 'long_term_incentive', 
                      'restricted_stock', 'director_fees']
email_features = ['to_messages', 'email_address', 'from_poi_to_this_person', 'from_messages', 
                  'from_this_person_to_poi', 'shared_receipt_with_poi']

numeric_columns = list(features[financial_features].
                       columns[list(features[financial_features].dtypes.isin([np.dtype('int'), np.dtype('float')]))])
numeric_columns = list(features[numeric_columns].
                       columns[list(features[numeric_columns].
                                    apply(lambda x:len(x.unique()) != 2))])
print("Numbers of remain columns: %i" % len(numeric_columns))

plt.figure(figsize=(16, 56))
for i, col in enumerate(numeric_columns):
    plt.subplot(13, 5, i+1)
    features.boxplot(col)
plt.tight_layout()
plt.show()
# Out:
# Numbers of remain columns: 14

# %% [markdown]
# # Outliers
# From figures above, it can see that some of the features may have outliers.
# * salary
# * deferral_payments
# * total_payments
# * bonus
# * deferred_income
# * total_stock_value
# * expenses
# * exercised_stock_options
# * other
# * long_term_incentive
# * restricted_stock
# * director_fees

# %%
features_temp = pd.concat([features, labels], axis=1)
features_temp.describe()
# Out:
#               bonus  deferral_payments  deferred_income  director_fees  \
# count  6.100000e+01       2.800000e+01     3.400000e+01      13.000000
# mean   1.147436e+06       6.344374e+05    -4.625664e+05   89397.846154
# std    1.505189e+06       8.603646e+05     8.095392e+05   41143.391399
# min    7.000000e+04      -1.025000e+05    -3.504386e+06    3285.000000
# 25%    4.500000e+05       7.656750e+04    -5.527032e+05  101250.000000
# 50%    7.500000e+05       1.951900e+05    -1.175340e+05  108579.000000
# 75%    1.000000e+06       8.342052e+05    -2.708325e+04  112492.000000
# max    8.000000e+06       2.964506e+06    -1.042000e+03  125034.000000
#
#        exercised_stock_options       expenses  from_messages  \
# count             8.100000e+01      73.000000      65.000000
# mean              2.985081e+06   51040.547945     711.323077
# std               6.004174e+06   47596.682104    2074.497628
# min               3.285000e+03     148.000000      12.000000
# ...

# %%
features_temp.describe().loc["std"].sort_values()
# Out:
# poi                          3.204966e-01
# from_this_person_to_poi      8.890141e+01
# from_poi_to_this_person      9.186321e+01
# shared_receipt_with_poi      1.165852e+03
# from_messages                2.074498e+03
# to_messages                  2.811677e+03
# director_fees                4.114339e+04
# expenses                     4.759668e+04
# salary                       1.716647e+05
# restricted_stock_deferred    2.051914e+05
# deferred_income              8.095392e+05
# deferral_payments            8.603646e+05
# long_term_incentive          9.504645e+05
# other                        1.341564e+06
# bonus                        1.505189e+06
# restricted_stock             2.498335e+06
# exercised_stock_options      6.004174e+06
# total_stock_value            7.182997e+06
# total_payments               1.056645e+07
# loan_advances                5.736404e+07
# Name: std, dtype: float64

# %% [markdown]
# Since the number of variables are too many to plot them all, I will use the 4 with the higher variance.

# %%
plt.figure(figsize=(15, 10))
sns.pairplot(
    data=features_temp, 
    vars=["total_payments", "exercised_stock_options", "restricted_stock", "total_stock_value"], 
    hue="poi")
plt.show()

# %%
features_temp.total_payments.nlargest(1)
# Out:
# 8    103559793.0
# Name: total_payments, dtype: float64

# %%
display(features.iloc[8])
# Out:
# name                                 LAY KENNETH L
# bonus                                        7e+06
# deferral_payments                           202911
# deferred_income                            -300000
# director_fees                                  NaN
# email_address                kenneth.lay@enron.com
# exercised_stock_options                3.43484e+07
# expenses                                     99832
# from_messages                                   36
# from_poi_to_this_person                        123
# from_this_person_to_poi                         16
# loan_advances                           8.1525e+07
# long_term_incentive                        3.6e+06
# other                                  1.03597e+07
# restricted_stock                       1.47617e+07
# restricted_stock_deferred                      NaN
# salary                                 1.07232e+06
# shared_receipt_with_poi                       2411
# ...

# %% [markdown]
# "LAY KENNETH L" is not an outlier, it is just the huge payment and stock value of the CEO and chairman of Enron, Kenneth Lay. Datapoints like this are not outliers.

# %%
for name in features_temp.name:
    try: 
        if re.match("^[A-Z]+\s[A-Z]+(\s[A-Z])?$", name):
            continue
        else:
            print(name)
    except: 
        pass
# Out:
# YEAGER F SCOTT
# GLISAN JR BEN F
# OVERDYKE JR JERE C
# PEREIRA PAULO V. FERRAZ
# GARLAND C KEVIN
# BLAKE JR. NORMAN P
# THE TRAVEL AGENCY IN THE PARK
# WALLS JR ROBERT H
# WHITE JR THOMAS E
# WINOKUR JR. HERBERT S
# SULLIVAN-SHAKLOVITZ COLLEEN

# %% [markdown]
# "THE TRAVEL AGENCY IN THE PARK" is not a name of an employee. Since it is not an employee we should remove it.

# %%
features_temp[features_temp.name == "THE TRAVEL AGENCY IN THE PARK"]
# Out:
#                              name  bonus  deferral_payments  deferred_income  \
# 65  THE TRAVEL AGENCY IN THE PARK    NaN                NaN              NaN
#
#     director_fees email_address  exercised_stock_options  expenses  \
# 65            NaN           NaN                      NaN       NaN
#
#     from_messages  from_poi_to_this_person  ...  long_term_incentive  \
# 65            NaN                      NaN  ...                  NaN
#
#        other  restricted_stock  restricted_stock_deferred  salary  \
# 65  362096.0               NaN                        NaN     NaN
#
#     shared_receipt_with_poi  to_messages  total_payments  total_stock_value  \
# 65                      NaN          NaN        362096.0                NaN
#
#     poi
# 65    0
#
# [1 rows x 22 columns]

# %%
features_temp = features_temp.drop(index=65, axis=0)

# %%
features, labels = split(features_temp)

# %% [markdown]
# # Emprical Cumulative Density Plot
# * [ECDF](https://zh.wikipedia.org/wiki/%E7%BB%8F%E9%AA%8C%E5%88%86%E5%B8%83%E5%87%BD%E6%95%B0)
# * [ECDF with Python](https://stackoverflow.com/questions/14006520/ecdf-in-python-without-step-function)
#
# **Why is the Empirical Cumulative Distribution Useful in Exploratory Data Analysis?**
#
# The empirical CDF is useful because
#
# 1. It approximates the true CDF well if the sample size (the number of data) is large, and knowing the distribution is helpful for statistical inference.
# 2. A plot of the empirical CDF can be visually compared to known CDFs of frequently used distributions to check if the data came from one of those common distributions.
# 3. It can visually display “how fast” the CDF increases to 1; plotting key quantiles like the quartiles can be useful to “get a feel” for the data.
#
# $$P(|ECDF(x)-CDF(x)|<\epsilon)\geq1-\frac{1}{4n\epsilon^2}$$
#
# $$1-\frac{1}{4n\times0.05^2}\geq0.9$$
#
# $$n\geq\frac{1}{4\times0.1\times0.05^2}=1000$$
#
# Therefore, if we want the probability of the error ($\epsilon=0.05$) to be at least 0.9, by Chebyshev's Inequality, we need at least 1000 samples.

# %%
plt.figure(figsize=(16, 16))
for i, feature in enumerate(financial_features):
    cdf = features[feature].value_counts().sort_index().cumsum()

    plt.subplot(4, 4, i+1)
    plt.plot(list(cdf.index), cdf/cdf.max())
    plt.xlabel('Value')
    plt.ylabel('ECDF')
    plt.xlim([cdf.index.min(), cdf.index.max()*1.05])
    plt.ylim([-0.05, 1.05])
    plt.title(feature + " ECDF Plot")
    plt.xticks(rotation=15)
    plt.xlabel(None)
    plt.grid()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16, 16))
for i, feature in enumerate(financial_features):
    plt.subplot(4, 4, i+1)
    sns.distplot(features[feature])
    plt.xticks(rotation=15)
    plt.xlabel(feature)
    plt.grid(axis="y")
plt.tight_layout()
plt.show()

# %%
## Calculating the correlation among features by Pearson method
df_copy = features.copy()
df_copy = df_copy.fillna(0)
correlation_dataframe = df_copy[financial_features + email_features].corr()

# Drawing a heatmap with the numeric values in each cell
plt.figure(figsize=(14, 10))
plt.title('Features correlation from the Enron POI dataset', fontsize=14, fontweight='bold', loc='center')

cbar_kws = {'orientation': "vertical", 'pad': 0.025, 'aspect': 70}
sns.heatmap(correlation_dataframe, annot=True, fmt='.2f', linewidths=.3, cbar_kws=cbar_kws)
plt.show()

# %% [markdown]
# # Create new features

# %%
# Reference from http://www.yannispappas.com/Fraud-Detection-Using-Machine-Learning/
data = features.copy()
data.loc[:, "salary_p"] = data.loc[:, "salary"]/data.loc[:, "total_payments"]
data.loc[:, "deferral_payments_p"] = data.loc[:, "deferral_payments"]/data.loc[:, "total_payments"]
data.loc[:, "loan_advances_p"] = data.loc[:, "loan_advances"]/data.loc[:, "total_payments"]
data.loc[:, "bonus_p"] = data.loc[:, "bonus"]/data.loc[:, "total_payments"]
data.loc[:, "deferred_income_p"] = data.loc[:, "deferred_income"]/data.loc[:, "total_payments"]
data.loc[:, "expenses_p"] = data.loc[:, "expenses"]/data.loc[:, "total_payments"]
data.loc[:, "other_p"] = data.loc[:, "other"]/data.loc[:, "total_payments"]
data.loc[:, "long_term_incentive_p"] = data.loc[:, "long_term_incentive"]/data.loc[:, "total_payments"]
data.loc[:, "director_fees_p"] = data.loc[:, "director_fees"]/data.loc[:, "total_payments"]

data.loc[:, "restricted_stock_deferred_p"] = data.loc[:, "restricted_stock_deferred"]/data.loc[:, "total_stock_value"]
data.loc[:, "exercised_stock_options_p"] = data.loc[:, "exercised_stock_options"]/data.loc[:, "total_stock_value"]
data.loc[:, "restricted_stock_p"] = data.loc[:, "restricted_stock"]/data.loc[:, "total_stock_value"]

data.loc[:, "from_poi_to_this_person_p"] = data.loc[:, "from_poi_to_this_person"]/data.loc[:, "to_messages"]
data.loc[:, "shared_receipt_with_poi_p"] = data.loc[:, "shared_receipt_with_poi"]/data.loc[:, "to_messages"]

data.loc[:, "from_this_person_to_poi_p"] = data.loc[:, "from_this_person_to_poi"]/data.loc[:, "from_messages"]
    
data.replace(to_replace=np.NaN, value=0, inplace=True)
data.replace(to_replace=np.inf, value=0, inplace=True)
data.replace(to_replace=-np.inf, value=0, inplace=True)

# %%
string_features = []
for dtype, feature in zip(features.dtypes, features.columns):
    if dtype == "object":
        string_features.append(feature)
string_features
# Out:
# ['name', 'email_address']

# %%
data_temp = data.drop(labels=string_features, axis=1)
data_temp
# Out:
#          bonus  deferral_payments  deferred_income  director_fees  \
# 0    1750000.0                0.0       -3504386.0            0.0
# 1    5600000.0                0.0              0.0            0.0
# 2     200000.0                0.0          -4167.0            0.0
# 3     800000.0                0.0              0.0            0.0
# 4    1250000.0                0.0        -262500.0            0.0
# ..         ...                ...              ...            ...
# 108   500000.0                0.0              0.0            0.0
# 109        0.0                0.0              0.0            0.0
# 110   300000.0                0.0              0.0            0.0
# 111        0.0                0.0              0.0            0.0
# 112   650000.0                0.0              0.0            0.0
#
#      exercised_stock_options  expenses  from_messages  \
# 0                 19794175.0   46950.0           18.0
# 1                 19250000.0   29336.0          108.0
# ...

# %% [markdown]
# # Feature Importance

# %%
def plot_feature_importance(features, labels):

    selector = SelectPercentile(percentile=100)
    x = selector.fit(features, labels)

    plt.figure(figsize=(15, 10))
    sns.barplot(y=features.columns, x=x.scores_)
    plt.grid()
    plt.show()

# %%
selector = SelectKBest(k=6)
data_temp = data.drop(labels=string_features, axis=1)
indices_to_keep = ~data_temp.isin([np.nan, np.inf, -np.inf]).any(1)
data_temp = data_temp[indices_to_keep].astype(np.float64)
selector.fit(data_temp, labels)
data_temp.columns[selector.get_support()].tolist()
# Out:
# ['bonus',
#  'exercised_stock_options',
#  'salary',
#  'total_stock_value',
#  'bonus_p',
#  'from_this_person_to_poi_p']

# %%
plot_feature_importance(data_temp, labels)

# %%
# Adding the proportions
features.loc[:, "long_term_incentive_p"] = features.loc[:, "long_term_incentive"]/features.loc[:, "total_payments"]
features.loc[:, "restricted_stock_deferred_p"] = features.loc[:, "restricted_stock_deferred"]/features.loc[:, "total_stock_value"]
features.loc[:, "from_this_person_to_poi_p"] = features.loc[:, "from_this_person_to_poi"]/features.loc[:, "from_messages"]
# Removing the original values.
features.drop("long_term_incentive", axis=1)
features.drop("restricted_stock_deferred", axis=1)
features.drop("from_this_person_to_poi", axis=1)
# Correcting NaN and infinity values created by zero divisions
features.replace(to_replace=np.NaN, value=0, inplace=True)
features.replace(to_replace=np.inf, value=0, inplace=True)
features.replace(to_replace=-np.inf, value=0, inplace=True)

# %%
features.head()
# Out:
#                    name      bonus  deferral_payments  deferred_income  \
# 0        RICE KENNETH D  1750000.0                0.0       -3504386.0
# 1    SKILLING JEFFREY K  5600000.0                0.0              0.0
# 2            SHELBY REX   200000.0                0.0          -4167.0
# 3      KOPPER MICHAEL J   800000.0                0.0              0.0
# 4  CALGER CHRISTOPHER F  1250000.0                0.0        -262500.0
#
#    director_fees                 email_address  exercised_stock_options  \
# 0            0.0            ken.rice@enron.com               19794175.0
# 1            0.0       jeff.skilling@enron.com               19250000.0
# 2            0.0          rex.shelby@enron.com                1624396.0
# 3            0.0      michael.kopper@enron.com                      0.0
# 4            0.0  christopher.calger@enron.com                      0.0
#
#    expenses  from_messages  from_poi_to_this_person  ...  restricted_stock  \
# ...

# %%
def transform_data(df, train_data=True, scale=None):
    
    # Get features and label
    if train_data: 
        # Remove "LOCKHART EUGENE E" and "THE TRAVEL AGENCY IN THE PARK" samples
        df = df.drop(index=107, axis=0)
        df = df.drop(index=65, axis=0)
        labels = df["poi"]
        features = df.drop(["poi"], axis=1)
    else: 
        labels = None
        features = df.copy()
    
    # Adding the proportions
    features.loc[:, "long_term_incentive_p"] = features.loc[:, "long_term_incentive"]/features.loc[:, "total_payments"]
    features.loc[:, "restricted_stock_deferred_p"] = features.loc[:, "restricted_stock_deferred"]/features.loc[:, "total_stock_value"]
    features.loc[:, "from_this_person_to_poi_p"] = features.loc[:, "from_this_person_to_poi"]/features.loc[:, "from_messages"]
    
    # Removing the original values.
    features.drop("long_term_incentive", axis=1)
    features.drop("restricted_stock_deferred", axis=1)
    features.drop("from_this_person_to_poi", axis=1)
    
    # Select numerical feature (float or integer)
    num_features = []
    for dtype, feature in zip(features.dtypes, features.columns):
        if dtype == 'float64' or dtype == 'int64':
            num_features.append(feature)
            
    # Fill nan
    imp_median = SimpleImputer(missing_values=np.nan, strategy='median')
    imp_median.fit(features[num_features])
    features = imp_median.transform(features[num_features])
    
    # Scale the data
    if scale is not None:
        if scale.lower() == "mmencoder":
            MMEncoder = MinMaxScaler()
            features = MMEncoder.fit_transform(features)
        elif scale.lower() == "ssencoder":
            SSEncoder = StandardScaler()
            features = SSEncoder.fit_transform(features)
        else:
            print("Only MinMaxScaler() and StandardScaler() are available.")
            
    return features, labels

# %%
# Read in data
df = pd.read_csv("train_data.csv")
features, labels = transform_data(df, scale=None)

# Split data (imbalanced)
# y_1_index, y_0_index = np.where(y_train==1)[0], np.where(y_train==0)[0]
# train_data_y1, test_data_y1, train_label_y1, test_label_y1 = train_test_split(
#     x_train[y_1_index], y_train[y_1_index], test_size=7, random_state=0)
# train_data_y0, test_data_y0, train_label_y0, test_label_y0 = train_test_split(
#     x_train[y_0_index], y_train[y_0_index], test_size=6, random_state=0)

# x_train, y_train = np.concatenate([train_data_y1, train_data_y0]), np.concatenate([train_label_y1, train_label_y0])
# x_valid, y_valid = np.concatenate([test_data_y1, test_data_y0]), np.concatenate([test_label_y1, test_label_y0])

# Split data
x_train, x_valid, y_train, y_valid = train_test_split(features, labels, test_size=0.3, random_state=417)

# %% [markdown]
# ![scoring function](https://github.com/penguinwang96825/ML100Days/blob/master/homework/Day051%20-%20Day53/scoring%20function.png?raw=true)

# %%
# xgboost
estimator = xgboost.XGBClassifier(n_jobs=multiprocessing.cpu_count(), random_state=2020)
n_estimators = [int(x) for x in np.linspace(100, 1000, 100)]
max_depth = [int(x) for x in np.linspace(5, 15, 10)]
gamma = [float(x) for x in np.linspace(0, 1, 10)]
learning_rate = [0.1, 0.01, 0.001]
param_grid = dict(
    n_estimators=n_estimators, 
    max_depth=max_depth, 
    gamma=gamma, 
    learning_rate=learning_rate)
rand_search = RandomizedSearchCV(
    estimator, 
    param_grid, 
    scoring="roc_auc_ovr", 
    cv=ShuffleSplit(n_splits=10, test_size=0.3, random_state=417), 
    n_jobs=multiprocessing.cpu_count(), 
    verbose=1)
rand_result = rand_search.fit(x_train, y_train)
print(rand_result.best_params_)
estimator = xgboost.XGBClassifier(**rand_result.best_params_)
estimator.fit(x_train, y_train)

# Evaluate step
y_pred = estimator.predict(x_valid)
y_prob = estimator.predict_proba(x_valid)
accuracy = metrics.accuracy_score(y_valid, y_pred)
roc_auc_score = metrics.roc_auc_score(y_valid, y_prob[:, 1])
print("Accuracy: {:.4f}".format(accuracy))
print("ROC AUC: {:.4f}".format(roc_auc_score))
print("Confusion matrix: \n{}".format(metrics.confusion_matrix(y_valid, y_pred)))
# Out:
# {'gamma': 0.0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 218}
# Accuracy: 0.9118
# ROC AUC: 0.8167
# Confusion matrix:
# [[30  0]
#  [ 3  1]]

# %%
# Evaluate step
y_pred = rand_search.predict(x_valid)
y_prob = rand_search.predict_proba(x_valid)
accuracy = metrics.accuracy_score(y_valid, y_pred)
roc_auc_score = metrics.roc_auc_score(y_valid, y_prob[:, 1])
print("Accuracy: {:.4f}".format(accuracy))
print("ROC AUC: {:.4f}".format(roc_auc_score))
print("Confusion matrix: \n{}".format(metrics.confusion_matrix(y_valid, y_pred)))
# Out:
# Accuracy: 0.9118
# ROC AUC: 0.8167
# Confusion matrix:
# [[30  0]
#  [ 3  1]]

# %%
# Read in test data
test = pd.read_csv("test_features.csv")
x_test, _ = transform_data(test, train_data=False, scale=None)

# %%
# Pass in model
y_prob = rand_search.predict_proba(x_test)[:, 1]

submit = pd.read_csv("sample_submission.csv")
submit['poi'] = y_prob
submit.to_csv('Submission_20200625_xgboost.csv', index=False)

# %%
# https://www.kaggle.com/c/2020-ml100marathon-midterm/submissions
! kaggle competitions submit -c 2020-ml100marathon-midterm -f Submission_20200623_xgboost.csv -m "ROC AUC OVR"
# Out:
# Successfully submitted to 2020_ML100Marathon Midterm
#   0%|          | 0.00/912 [00:00<?, ?B/s]
# 100%|██████████| 912/912 [00:04<00:00, 184B/s]
