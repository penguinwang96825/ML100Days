# %%
'''Main'''
import numpy as np
import pandas as pd
'''Data Viz'''
import matplotlib.pyplot as plt
import seaborn as sns
#plt.style.use('seaborn')
plt.rcParams['figure.figsize'] = [16, 9]
plt.rcParams['figure.dpi'] = 300
plt.rcParams['font.size'] = 20
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['axes.titlesize'] = 18
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['font.family'] = 'serif'
# %matplotlib inline
'''Data Prep'''
from sklearn import preprocessing as pp
from scipy.stats import pearsonr
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
'''Metrics'''
from sklearn.metrics import log_loss, accuracy_score, f1_score
from sklearn.metrics import precision_recall_curve, average_precision_score
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.metrics import confusion_matrix, classification_report
'''Algos'''
from sklearn.linear_model import LogisticRegression
import lightgbm as lgb
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ReduceLROnPlateau,EarlyStopping

# %%
data_original = pd.read_csv("../data/train_data.csv") 
data_original.head()
# Out:
#                    name      bonus  deferral_payments  deferred_income  \
# 0        RICE KENNETH D  1750000.0                NaN       -3504386.0
# 1    SKILLING JEFFREY K  5600000.0                NaN              NaN
# 2            SHELBY REX   200000.0                NaN          -4167.0
# 3      KOPPER MICHAEL J   800000.0                NaN              NaN
# 4  CALGER CHRISTOPHER F  1250000.0                NaN        -262500.0
#
#    director_fees                 email_address  exercised_stock_options  \
# 0            NaN            ken.rice@enron.com               19794175.0
# 1            NaN       jeff.skilling@enron.com               19250000.0
# 2            NaN          rex.shelby@enron.com                1624396.0
# 3            NaN      michael.kopper@enron.com                      NaN
# 4            NaN  christopher.calger@enron.com                      NaN
#
#    expenses  from_messages  from_poi_to_this_person  ...  long_term_incentive  \
# 0   46950.0           18.0                     42.0  ...            1617011.0
# 1   29336.0          108.0                     88.0  ...            1920000.0
# 2   22884.0           39.0                     13.0  ...                  NaN
# 3  118134.0            NaN                      NaN  ...             602671.0
# 4   35818.0          144.0                    199.0  ...             375304.0
#
#        other   poi  restricted_stock  restricted_stock_deferred     salary  \
# 0   174839.0  True         2748364.0                        NaN   420636.0
# 1    22122.0  True         6843672.0                        NaN  1111258.0
# 2  1573324.0  True          869220.0                        NaN   211844.0
# 3   907502.0  True          985032.0                        NaN   224305.0
# 4      486.0  True          126027.0                        NaN   240189.0
#
#    shared_receipt_with_poi  to_messages  total_payments  total_stock_value
# 0                    864.0        905.0        505050.0         22542539.0
# 1                   2042.0       3627.0       8682716.0         26093672.0
# 2                     91.0        225.0       2003885.0          2493616.0
# 3                      NaN          NaN       2652612.0           985032.0
# 4                   2188.0       2598.0       1639297.0           126027.0
#
# [5 rows x 22 columns]

# %%
def process_data(data):
    data = data.query('name!="THE TRAVEL AGENCY IN THE PARK"')
    data = data.query('name!="LOCKHART EUGENE E"')
    drop_feature = ["email_address", "name"]
    data = data.drop(labels=drop_feature, axis=1)
    col = data.columns.tolist()
    imputer = SimpleImputer(missing_values=np.nan, copy=False, strategy="mean")
    imputer = imputer.fit(data)
    data = imputer.transform(data)
    data = pd.DataFrame(data, columns=col)
    print(f"Shape of data: {data.shape}")
    return data

def expand_features(data):
    data.loc[:, "salary_p"] = data.loc[:, "salary"]/data.loc[:, "total_payments"]
    data.loc[:, "deferral_payments_p"] = data.loc[:, "deferral_payments"]/data.loc[:, "total_payments"]
    data.loc[:, "loan_advances_p"] = data.loc[:, "loan_advances"]/data.loc[:, "total_payments"]
    data.loc[:, "bonus_p"] = data.loc[:, "bonus"]/data.loc[:, "total_payments"]
    data.loc[:, "deferred_income_p"] = data.loc[:, "deferred_income"]/data.loc[:, "total_payments"]
    data.loc[:, "expenses_p"] = data.loc[:, "expenses"]/data.loc[:, "total_payments"]
    data.loc[:, "other_p"] = data.loc[:, "other"]/data.loc[:, "total_payments"]
    data.loc[:, "long_term_incentive_p"] = data.loc[:, "long_term_incentive"]/data.loc[:, "total_payments"]
    data.loc[:, "director_fees_p"] = data.loc[:, "director_fees"]/data.loc[:, "total_payments"]
    data.loc[:, "restricted_stock_deferred_p"] = data.loc[:, "restricted_stock_deferred"]/data.loc[:, "total_stock_value"]
    data.loc[:, "exercised_stock_options_p"] = data.loc[:, "exercised_stock_options"]/data.loc[:, "total_stock_value"]
    data.loc[:, "restricted_stock_p"] = data.loc[:, "restricted_stock"]/data.loc[:, "total_stock_value"]
    data.loc[:, "from_poi_to_this_person_p"] = data.loc[:, "from_poi_to_this_person"]/data.loc[:, "to_messages"]
    data.loc[:, "shared_receipt_with_poi_p"] = data.loc[:, "shared_receipt_with_poi"]/data.loc[:, "to_messages"]
    data.loc[:, "from_this_person_to_poi_p"] = data.loc[:, "from_this_person_to_poi"]/data.loc[:, "from_messages"]
    data.loc[:, "long_term_incentive_p"] = data.loc[:, "long_term_incentive"]/data.loc[:, "total_payments"]
    data.loc[:, "restricted_stock_deferred_p"] = data.loc[:, "restricted_stock_deferred"]/data.loc[:, "total_stock_value"]
    data.loc[:, "from_this_person_to_poi_p"] = data.loc[:, "from_this_person_to_poi"]/data.loc[:, "from_messages"]
    data.drop("long_term_incentive", axis=1)
    data.drop("restricted_stock_deferred", axis=1)
    data.drop("from_this_person_to_poi", axis=1)
    return data

# %%
def plot_corr(data):
   
    ax1 = data.corrwith(data.poi).plot.bar(figsize=(20, 10),
         title = "Correlation with class",
         fontsize=18, color='r',
         rot=45, grid=True)
    ax1.title.set_size(28)
    ax1.set_xticklabels(data.columns.tolist(), rotation=90)
    
    sns.set(style="white")
    cmap = sns.diverging_palette(220, 20, as_cmap=True)
    
    corr =data.corr()
    sns.clustermap(corr, cmap=cmap,
                  linewidths=1, linecolor='w')
                 
data_processed = process_data(data_original)
data_processed = expand_features(data_processed)
plot_corr(data_processed)
# Out:
# Shape of data: (111, 20)

# %%
def metrics_summary(true_label, prediction_prob, Threshold=0.5):
    
    #basically, slearn provides all the functions for metrics.
    average_precision = average_precision_score(true_label
    ,prediction_prob)
    fpr, tpr, thresholds = roc_curve(true_label, prediction_prob)
    areaUnderROC = auc(fpr, tpr)
    
    prediction_int = prediction_prob > Threshold
    
    accuracy = accuracy_score(true_label, prediction_int)
            
    print(f'accuracy: {accuracy}')
    print(f"average_precision: {average_precision}")
    print(f'areaUnderROC: {areaUnderROC } \n')
    print('*'*60)
    print(' '*20, 'classification_report')
    print('*'*60, "\n")
    print(classification_report(true_label, prediction_int))
    
    print('*'*60)
    print(' '*20, 'confusion_matrix \n')
    print('*'*60, "\n")
    display(confusion_matrix(true_label, prediction_int))
    print("\n")
    
    # precision_recall_curve and areaUnderROC 
    precision, recall, thresholds = precision_recall_curve(true_label, prediction_int)
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,9))
    
    ax1.step(recall, precision, color='k', alpha=0.7, where='post')
    ax1.fill_between(recall, precision, step='post', 
    alpha=0.3,color='k')
    ax1.set_xlabel('Recall', fontname="Arial", fontsize=24)
    ax1.set_ylabel('Precision', fontname="Arial", fontsize=24) 
    ax1.tick_params(labelsize=20)
     
    ax1.set_title('Precision-Recall curve: Average Precision = {0:0.2f}'.format(average_precision), 
                  fontsize=24, 
                  fontname="Arial")        
               
    ax2.plot(fpr, tpr, color='r', lw=2, label='ROC curve')
    ax2.plot([0, 1], [0, 1], color='k', lw=2, linestyle='--')
    ax2.tick_params(labelsize=20)
    ax2.set_xlabel('False Positive Rate', fontname="Arial", fontsize=24)
    ax2.set_ylabel('True Positive Rate', fontname="Arial", fontsize=24)
    ax2.set_title('areaUnderROC = {0:0.2f}'.format(areaUnderROC), fontsize=24, fontname="Arial",)    
    ax2.legend(loc="lower right", fontsize=24, fancybox=True) 
    # Adjust the subplot layout, because the logit one may take more space
    # than usual, due to y-tick labels like "1 - 10^{-3}"
    # plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10,
    # right=0.95, hspace=0.25,wspace=0.35)

# %%
#Normalize training and testing data
def scale_data(x_train, x_test=None):   
    features_to_scale = x_train.copy().columns
    scaler = pp.StandardScaler()
    print(scaler.fit(x_train[features_to_scale]))
    
    x_train.loc[:, features_to_scale] = \
    scaler.transform(x_train[features_to_scale])
    
    #normalize test dataset with the mean and std of train data set 
    x_test.loc[:, features_to_scale] = scaler.transform(x_test[features_to_scale])
    
    return x_train, x_test

#seperate input and labels    
def get_x_y(data):
    data_x = data.copy()
    data_y = data_x.pop("poi").astype(int)
    return data_x, data_y

#split the train and test data
def data_split(data_x, data_y):
    x_train, x_test, y_train, y_test = \
          train_test_split(data_x,data_y,test_size=0.25,
          stratify=data_y,random_state=2020)                                               
    return  x_train, x_test, y_train, y_test

#put all together
def data_process(data):
    data_x, data_y = get_x_y(data)
    
    x_train, x_test, y_train, y_test = data_split(data_x, data_y)
    
    #do not touch the test data by any means!!!!
    x_train, x_test = scale_data(x_train, x_test)
    
    return  x_train, x_test, y_train, y_test

# %%
x_train, x_test_original, y_train, y_test_original = data_process(data_processed)
x_train.shape, x_test_original.shape, y_train.shape, y_test_original.shape
# Out:
# StandardScaler()
# C:\Users\yangwang\Anaconda3\envs\nlp\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yangwang\Anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\yangwang\Anaconda3\envs\nlp\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# C:\Users\yangwang\Anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# ((83, 34), (28, 34), (83,), (28,))

# %%
from sklearn.model_selection import GridSearchCV

def build_model_1(x_train, y_train):
    logitreg_parameters = {'C': np.power(10.0, np.arange(-9, 1)),
                           'solver' : ('lbfgs', 'liblinear') }
    model_1 = LogisticRegression(class_weight='balanced', warm_start=True, max_iter = 300, random_state=2020)
    logitreg_grid = GridSearchCV(model_1, param_grid = logitreg_parameters,scoring = 'f1', n_jobs = 1, cv=5)                     
    logitreg_grid.fit(x_train, y_train) 
    return logitreg_grid

model_1 = build_model_1(x_train, y_train)

# %%
# 0 and 1 two clasese
y_pred_prob_test_1 = model_1.predict_proba(x_test_original)[:,1]
# number of fraud is 123 in test dataset
Threshold = 0.1
y_pred_int_test_1 = y_pred_prob_test_1 > Threshold
pd.Series(y_pred_int_test_1).value_counts()
# Out:
# True     27
# False     1
# dtype: int64

# %%
metrics_summary(y_test_original, y_pred_int_test_1)
# Out:
# accuracy: 0.14285714285714285
# average_precision: 0.1111111111111111
# areaUnderROC: 0.52
#
# ************************************************************
#                      classification_report
# ************************************************************
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.04      0.08        25
#            1       0.11      1.00      0.20         3
#
#     accuracy                           0.14        28
#    macro avg       0.56      0.52      0.14        28
# weighted avg       0.90      0.14      0.09        28
#
# ************************************************************
#                      confusion_matrix
#
# ************************************************************
# array([[ 1, 24],
#        [ 0,  3]], dtype=int64)

# %%
#prepare data 
x_train_, x_cv, y_train_, y_cv = \
    train_test_split(x_train, y_train,
                    test_size=0.25,
                    stratify=y_train,
                    random_state=2020)
def build_model_2(x_train, y_train, x_cv, y_cv ):
    #most of the parsmeters are default
    params_lightGB = {
    'task': 'train',
    'application':'binary',
    'num_class':1,
    'boosting': 'gbdt',
    'objective': 'binary',
    'metric': 'binary_logloss',
    'metric_freq':50,
    'is_training_metric':False,
    'max_depth':4,
    'num_leaves': 31,
    'learning_rate': 0.01,
    'feature_fraction': 1.0,
    'bagging_fraction': 1.0,
    'bagging_freq': 0,
    'bagging_seed': 2018,
    'verbose': 0,
    'num_threads':16
    }
    lgb_train = lgb.Dataset(x_train, y_train)
    lgb_eval = lgb.Dataset(x_cv, y_cv, reference=lgb_train)
    model_2 = lgb.train(params_lightGB, lgb_train,
                    num_boost_round=2000,
                    valid_sets=lgb_eval,
                    early_stopping_rounds=200,
                    verbose_eval=False)
    return model_2
x_train_.shape, y_train_.shape, x_cv.shape, y_cv.shape
# Out:
# ((62, 34), (62,), (21, 34), (21,))

# %%
model_2 = build_model_2(x_train_, y_train_, x_cv, y_cv)
y_pred_prob_test_2 = model_2.predict(x_test_original)
y_pred_int_test_2 = y_pred_prob_test_2 > Threshold
pd.DataFrame(y_pred_int_test_2).value_counts()
# Out:
# [LightGBM] [Warning] objective is set=binary, application=binary will be ignored. Current value: objective=binary
# [LightGBM] [Warning] objective is set=binary, application=binary will be ignored. Current value: objective=binary
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000201 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Warning] objective is set=binary, application=binary will be ignored. Current value: objective=binary
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# True     14
# False    14
# dtype: int64

# %%
metrics_summary(y_test_original, y_pred_int_test_2)
# Out:
# accuracy: 0.4642857142857143
# average_precision: 0.09523809523809525
# areaUnderROC: 0.4066666666666666
#
# ************************************************************
#                      classification_report
# ************************************************************
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.48      0.62        25
#            1       0.07      0.33      0.12         3
#
#     accuracy                           0.46        28
#    macro avg       0.46      0.41      0.37        28
# weighted avg       0.77      0.46      0.56        28
#
# ************************************************************
#                      confusion_matrix
#
# ************************************************************
# array([[12, 13],
#        [ 2,  1]], dtype=int64)

# %%
callbacks = [EarlyStopping(monitor='loss', patience=3), 
             ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=0.001)]

def build_model_3(x_train, y_train, x_cv, y_cv, input_dim=34): 
    model_3 = Sequential([
                Dense(input_dim = input_dim, units = 32, 
                      activation  = 'relu'),
                Dense(units = 16, activation =  'relu'),
                #Dropout(0.5),
                Dense(units = 8, activation =  'relu'),
                Dense(units =1, activation = 'sigmoid'),])
    model_3.compile(optimizer = 'adam', 
                 loss = 'binary_crossentropy', 
                 metrics = ['accuracy'])
    
    model_3.fit(x_train, y_train, 
              validation_data = (x_cv, y_cv),
              batch_size = 64, 
              epochs = 50,
              callbacks=callbacks)
    
    return model_3

# %%
model_3 = build_model_3(x_train_, y_train_, x_cv, y_cv, input_dim=34)
y_pred_prob_test_3 = model_3.predict(x_test_original)
y_pred_int_test_3 = y_pred_prob_test_3 > Threshold
y_pred_int_test_3.shape
pd.DataFrame(y_pred_int_test_3).value_counts()
# Out:
# Epoch 1/50
# 1/1 [==============================] - 0s 471ms/step - loss: 0.5779 - accuracy: 0.8871 - val_loss: 0.7007 - val_accuracy: 0.8571
# Epoch 2/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.5662 - accuracy: 0.8871 - val_loss: 0.6934 - val_accuracy: 0.8571
# Epoch 3/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.5546 - accuracy: 0.8871 - val_loss: 0.6860 - val_accuracy: 0.8571
# Epoch 4/50
# 1/1 [==============================] - 0s 34ms/step - loss: 0.5430 - accuracy: 0.8871 - val_loss: 0.6785 - val_accuracy: 0.8571
# Epoch 5/50
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5318 - accuracy: 0.8871 - val_loss: 0.6710 - val_accuracy: 0.8571
# Epoch 6/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.5207 - accuracy: 0.8871 - val_loss: 0.6637 - val_accuracy: 0.8571
# Epoch 7/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.5096 - accuracy: 0.8871 - val_loss: 0.6563 - val_accuracy: 0.8571
# Epoch 8/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4987 - accuracy: 0.8871 - val_loss: 0.6488 - val_accuracy: 0.8571
# Epoch 9/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4881 - accuracy: 0.8871 - val_loss: 0.6418 - val_accuracy: 0.8571
# Epoch 10/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4776 - accuracy: 0.8871 - val_loss: 0.6352 - val_accuracy: 0.8571
# Epoch 11/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4673 - accuracy: 0.8871 - val_loss: 0.6287 - val_accuracy: 0.8571
# Epoch 12/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4573 - accuracy: 0.8871 - val_loss: 0.6223 - val_accuracy: 0.8571
# Epoch 13/50
# 1/1 [==============================] - 0s 87ms/step - loss: 0.4472 - accuracy: 0.8871 - val_loss: 0.6161 - val_accuracy: 0.8571
# Epoch 14/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4374 - accuracy: 0.8871 - val_loss: 0.6108 - val_accuracy: 0.8571
# Epoch 15/50
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4276 - accuracy: 0.8871 - val_loss: 0.6058 - val_accuracy: 0.8571
# Epoch 16/50
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4181 - accuracy: 0.8871 - val_loss: 0.6010 - val_accuracy: 0.8571
# Epoch 17/50
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4088 - accuracy: 0.8871 - val_loss: 0.5962 - val_accuracy: 0.8571
# Epoch 18/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3998 - accuracy: 0.8871 - val_loss: 0.5914 - val_accuracy: 0.8571
# Epoch 19/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3910 - accuracy: 0.8871 - val_loss: 0.5867 - val_accuracy: 0.8571
# Epoch 20/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3823 - accuracy: 0.8871 - val_loss: 0.5823 - val_accuracy: 0.8571
# Epoch 21/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3739 - accuracy: 0.8871 - val_loss: 0.5779 - val_accuracy: 0.8571
# Epoch 22/50
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3657 - accuracy: 0.8871 - val_loss: 0.5738 - val_accuracy: 0.8571
# Epoch 23/50
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3577 - accuracy: 0.8871 - val_loss: 0.5698 - val_accuracy: 0.8571
# Epoch 24/50
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3499 - accuracy: 0.8871 - val_loss: 0.5659 - val_accuracy: 0.8571
# Epoch 25/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3424 - accuracy: 0.8871 - val_loss: 0.5619 - val_accuracy: 0.8571
# Epoch 26/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3350 - accuracy: 0.8871 - val_loss: 0.5580 - val_accuracy: 0.8571
# Epoch 27/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3278 - accuracy: 0.8871 - val_loss: 0.5540 - val_accuracy: 0.8571
# Epoch 28/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3210 - accuracy: 0.8871 - val_loss: 0.5501 - val_accuracy: 0.8571
# Epoch 29/50
# 1/1 [==============================] - ETA: 0s - loss: 0.3142 - accuracy: 0.88 - 0s 29ms/step - loss: 0.3142 - accuracy: 0.8871 - val_loss: 0.5461 - val_accuracy: 0.8571
# Epoch 30/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3077 - accuracy: 0.8871 - val_loss: 0.5420 - val_accuracy: 0.8571
# Epoch 31/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3013 - accuracy: 0.8871 - val_loss: 0.5377 - val_accuracy: 0.8571
# Epoch 32/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2951 - accuracy: 0.8871 - val_loss: 0.5334 - val_accuracy: 0.8571
# Epoch 33/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2889 - accuracy: 0.8871 - val_loss: 0.5291 - val_accuracy: 0.8571
# Epoch 34/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2828 - accuracy: 0.8871 - val_loss: 0.5247 - val_accuracy: 0.8571
# Epoch 35/50
# 1/1 [==============================] - 0s 81ms/step - loss: 0.2767 - accuracy: 0.8871 - val_loss: 0.5203 - val_accuracy: 0.8571
# Epoch 36/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2711 - accuracy: 0.8871 - val_loss: 0.5160 - val_accuracy: 0.8571
# Epoch 37/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2655 - accuracy: 0.8871 - val_loss: 0.5120 - val_accuracy: 0.8571
# Epoch 38/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2601 - accuracy: 0.8871 - val_loss: 0.5086 - val_accuracy: 0.8571
# Epoch 39/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2550 - accuracy: 0.8871 - val_loss: 0.5053 - val_accuracy: 0.8571
# Epoch 40/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2499 - accuracy: 0.8871 - val_loss: 0.5021 - val_accuracy: 0.8571
# Epoch 41/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2449 - accuracy: 0.8871 - val_loss: 0.4990 - val_accuracy: 0.8571
# Epoch 42/50
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2401 - accuracy: 0.8871 - val_loss: 0.4961 - val_accuracy: 0.8571
# Epoch 43/50
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2354 - accuracy: 0.8871 - val_loss: 0.4934 - val_accuracy: 0.8571
# Epoch 44/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2308 - accuracy: 0.8871 - val_loss: 0.4908 - val_accuracy: 0.8571
# Epoch 45/50
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2262 - accuracy: 0.8871 - val_loss: 0.4883 - val_accuracy: 0.8571
# Epoch 46/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2216 - accuracy: 0.8871 - val_loss: 0.4857 - val_accuracy: 0.8571
# Epoch 47/50
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2171 - accuracy: 0.8871 - val_loss: 0.4831 - val_accuracy: 0.8571
# Epoch 48/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2127 - accuracy: 0.8871 - val_loss: 0.4805 - val_accuracy: 0.8571
# Epoch 49/50
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2084 - accuracy: 0.8871 - val_loss: 0.4779 - val_accuracy: 0.8571
# Epoch 50/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2043 - accuracy: 0.8871 - val_loss: 0.4758 - val_accuracy: 0.8571
# False    18
# True     10
# dtype: int64

# %%
metrics_summary(y_test_original, y_pred_int_test_3)
# Out:
# accuracy: 0.75
# average_precision: 0.3
# areaUnderROC: 0.86
#
# ************************************************************
#                      classification_report
# ************************************************************
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.72      0.84        25
#            1       0.30      1.00      0.46         3
#
#     accuracy                           0.75        28
#    macro avg       0.65      0.86      0.65        28
# weighted avg       0.92      0.75      0.80        28
#
# ************************************************************
#                      confusion_matrix
#
# ************************************************************
# array([[18,  7],
#        [ 0,  3]], dtype=int64)

# %%
def data_stack( x, y, m_1=model_1, m_2=model_2, m_3=model_3):
    '''
    x: features
    y: labels
    m_1, m_2, m_3: 3 models
    '''
    # build a container to hold all the prediction from 3 models
    pred_all = pd.DataFrame(data=[], index=y.index)
    pred_1 = m_1.predict_proba(x)[:,1]
    pred_1_df = pd.DataFrame(pred_1, index=y.index)
    pred_2 = m_2.predict(x,num_iteration=m_2.best_iteration)
                    
    pred_2_df = pd.DataFrame(pred_2, index=y.index)
    pred_3 = m_3.predict(x).reshape(x.shape[0]) #to 1D shape
    pred_3_df = pd.DataFrame(pred_3, index=y.index)
   # join all the predictions together
    pred_all = pred_all.join(pred_1_df.astype(float),
                             how='left',rsuffix="0")\
                       .join(pred_2_df.astype(float),
                             how='left',rsuffix="1")\
                       .join(pred_3_df.astype(float),
                             how='left',rsuffix="2")
    pred_all.columns = ['pred_1', 'pred_2','pred_3']
    # final training data will be the merge of training data and all the predictions
    x_pred = x.merge(pred_all, \
                    left_index=True, right_index=True)
    
    return x_pred

# %%
x_train_stack = data_stack(x_train, y_train)
x_train_stack.shape
# Out:
# (83, 37)

# %%
x_test_stack = data_stack(x_test_original, y_test_original)
x_test_stack.shape
# Out:
# (28, 37)

# %%
#normalize training and testing data
x_train_stack, x_test_stack = scale_data(x_train_stack,  x_test_stack)
#split the traning data to train and validation
x_train_stack_, x_cv_stack, y_train_, y_cv_ = \
    train_test_split(x_train_stack, y_train,
                    test_size=0.25,
                    stratify=y_train,
                    random_state=2020)
#stratify mean samplling with the ratio of each class percentage in #all data.
x_train_stack_.shape, x_cv_stack.shape, y_train_.shape,  y_cv.shape
# Out:
# StandardScaler()
# ((62, 37), (21, 37), (62,), (21,))

# %%
model_2_stack = build_model_2(x_train_stack_, y_train_, x_cv_stack, y_cv_)
y_pred_prob_test_2_stack = model_2_stack.predict(x_test_stack)
y_pred_int_test_2_stack = y_pred_prob_test_2_stack > Threshold
pd.DataFrame(y_pred_int_test_2_stack).value_counts()
# Out:
# [LightGBM] [Warning] objective is set=binary, application=binary will be ignored. Current value: objective=binary
# [LightGBM] [Warning] objective is set=binary, application=binary will be ignored. Current value: objective=binary
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000233 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] objective is set=binary, application=binary will be ignored. Current value: objective=binary
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# False    17
# True     11
# dtype: int64

# %%
metrics_summary(y_test_original, y_pred_int_test_2_stack)
# Out:
# accuracy: 0.6428571428571429
# average_precision: 0.15692640692640694
# areaUnderROC: 0.6533333333333333
#
# ************************************************************
#                      classification_report
# ************************************************************
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.64      0.76        25
#            1       0.18      0.67      0.29         3
#
#     accuracy                           0.64        28
#    macro avg       0.56      0.65      0.52        28
# weighted avg       0.86      0.64      0.71        28
#
# ************************************************************
#                      confusion_matrix
#
# ************************************************************
# array([[16,  9],
#        [ 1,  2]], dtype=int64)

# %%
model_3_stack = build_model_3(x_train_stack_, y_train_, x_cv_stack, y_cv_, input_dim=37)
y_pred_prob_test_3_stack = model_3_stack.predict(x_test_stack)
y_pred_int_test_3_stack = y_pred_prob_test_3_stack > Threshold
y_pred_int_test_3_stack.shape
pd.DataFrame(y_pred_int_test_3_stack).value_counts()
# Out:
# Epoch 1/50
# 1/1 [==============================] - 0s 345ms/step - loss: 0.6441 - accuracy: 0.8871 - val_loss: 0.5922 - val_accuracy: 0.8571
# Epoch 2/50
# 1/1 [==============================] - 0s 89ms/step - loss: 0.6324 - accuracy: 0.8871 - val_loss: 0.5885 - val_accuracy: 0.8571
# Epoch 3/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.6209 - accuracy: 0.8871 - val_loss: 0.5851 - val_accuracy: 0.8571
# Epoch 4/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6097 - accuracy: 0.8871 - val_loss: 0.5814 - val_accuracy: 0.8571
# Epoch 5/50
# 1/1 [==============================] - 0s 27ms/step - loss: 0.5993 - accuracy: 0.8871 - val_loss: 0.5776 - val_accuracy: 0.8571
# Epoch 6/50
# 1/1 [==============================] - 0s 30ms/step - loss: 0.5890 - accuracy: 0.8871 - val_loss: 0.5737 - val_accuracy: 0.8571
# Epoch 7/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.5789 - accuracy: 0.8871 - val_loss: 0.5697 - val_accuracy: 0.8571
# Epoch 8/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.5689 - accuracy: 0.8871 - val_loss: 0.5654 - val_accuracy: 0.8571
# Epoch 9/50
# 1/1 [==============================] - 0s 30ms/step - loss: 0.5590 - accuracy: 0.8871 - val_loss: 0.5610 - val_accuracy: 0.8571
# Epoch 10/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.5494 - accuracy: 0.8871 - val_loss: 0.5568 - val_accuracy: 0.8571
# Epoch 11/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.5400 - accuracy: 0.8871 - val_loss: 0.5523 - val_accuracy: 0.8571
# Epoch 12/50
# 1/1 [==============================] - 0s 30ms/step - loss: 0.5307 - accuracy: 0.8871 - val_loss: 0.5475 - val_accuracy: 0.8571
# Epoch 13/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.5214 - accuracy: 0.8871 - val_loss: 0.5424 - val_accuracy: 0.8571
# Epoch 14/50
# 1/1 [==============================] - ETA: 0s - loss: 0.5124 - accuracy: 0.88 - 0s 28ms/step - loss: 0.5124 - accuracy: 0.8871 - val_loss: 0.5373 - val_accuracy: 0.8571
# Epoch 15/50
# 1/1 [==============================] - ETA: 0s - loss: 0.5034 - accuracy: 0.88 - 0s 29ms/step - loss: 0.5034 - accuracy: 0.8871 - val_loss: 0.5320 - val_accuracy: 0.8571
# Epoch 16/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4945 - accuracy: 0.8871 - val_loss: 0.5266 - val_accuracy: 0.8571
# Epoch 17/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4855 - accuracy: 0.8871 - val_loss: 0.5212 - val_accuracy: 0.8571
# Epoch 18/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4765 - accuracy: 0.8871 - val_loss: 0.5155 - val_accuracy: 0.8571
# Epoch 19/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4675 - accuracy: 0.8871 - val_loss: 0.5097 - val_accuracy: 0.8571
# Epoch 20/50
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4585 - accuracy: 0.8871 - val_loss: 0.5038 - val_accuracy: 0.8571
# Epoch 21/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4497 - accuracy: 0.8871 - val_loss: 0.4980 - val_accuracy: 0.8571
# Epoch 22/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4410 - accuracy: 0.8871 - val_loss: 0.4923 - val_accuracy: 0.8571
# Epoch 23/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4322 - accuracy: 0.8871 - val_loss: 0.4867 - val_accuracy: 0.8571
# Epoch 24/50
# 1/1 [==============================] - 0s 88ms/step - loss: 0.4234 - accuracy: 0.8871 - val_loss: 0.4812 - val_accuracy: 0.8571
# Epoch 25/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4146 - accuracy: 0.8871 - val_loss: 0.4760 - val_accuracy: 0.8571
# Epoch 26/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4059 - accuracy: 0.8871 - val_loss: 0.4707 - val_accuracy: 0.8571
# Epoch 27/50
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3973 - accuracy: 0.8871 - val_loss: 0.4658 - val_accuracy: 0.8571
# Epoch 28/50
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3887 - accuracy: 0.8871 - val_loss: 0.4610 - val_accuracy: 0.8571
# Epoch 29/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3803 - accuracy: 0.8871 - val_loss: 0.4564 - val_accuracy: 0.8571
# Epoch 30/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3720 - accuracy: 0.8871 - val_loss: 0.4520 - val_accuracy: 0.8571
# Epoch 31/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3638 - accuracy: 0.8871 - val_loss: 0.4478 - val_accuracy: 0.8571
# Epoch 32/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3557 - accuracy: 0.8871 - val_loss: 0.4438 - val_accuracy: 0.8571
# Epoch 33/50
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3477 - accuracy: 0.8871 - val_loss: 0.4403 - val_accuracy: 0.8571
# Epoch 34/50
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3397 - accuracy: 0.8871 - val_loss: 0.4370 - val_accuracy: 0.8571
# Epoch 35/50
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3319 - accuracy: 0.8871 - val_loss: 0.4340 - val_accuracy: 0.8571
# Epoch 36/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3242 - accuracy: 0.8871 - val_loss: 0.4312 - val_accuracy: 0.8571
# Epoch 37/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3167 - accuracy: 0.8871 - val_loss: 0.4287 - val_accuracy: 0.8571
# Epoch 38/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3093 - accuracy: 0.8871 - val_loss: 0.4267 - val_accuracy: 0.8571
# Epoch 39/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3022 - accuracy: 0.8871 - val_loss: 0.4252 - val_accuracy: 0.8571
# Epoch 40/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2953 - accuracy: 0.8871 - val_loss: 0.4239 - val_accuracy: 0.8571
# Epoch 41/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2886 - accuracy: 0.8871 - val_loss: 0.4229 - val_accuracy: 0.8571
# Epoch 42/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2819 - accuracy: 0.8871 - val_loss: 0.4222 - val_accuracy: 0.8571
# Epoch 43/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2753 - accuracy: 0.8871 - val_loss: 0.4217 - val_accuracy: 0.8571
# Epoch 44/50
# 1/1 [==============================] - ETA: 0s - loss: 0.2689 - accuracy: 0.88 - 0s 28ms/step - loss: 0.2689 - accuracy: 0.8871 - val_loss: 0.4213 - val_accuracy: 0.8571
# Epoch 45/50
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2627 - accuracy: 0.8871 - val_loss: 0.4212 - val_accuracy: 0.8571
# Epoch 46/50
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2567 - accuracy: 0.8871 - val_loss: 0.4208 - val_accuracy: 0.8571
# Epoch 47/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2509 - accuracy: 0.8871 - val_loss: 0.4207 - val_accuracy: 0.8571
# Epoch 48/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2454 - accuracy: 0.8871 - val_loss: 0.4209 - val_accuracy: 0.8571
# Epoch 49/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2399 - accuracy: 0.8871 - val_loss: 0.4213 - val_accuracy: 0.8571
# Epoch 50/50
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2347 - accuracy: 0.8871 - val_loss: 0.4218 - val_accuracy: 0.8571
# True     15
# False    13
# dtype: int64

# %%
metrics_summary(y_test_original, y_pred_int_test_3_stack)
# Out:
# accuracy: 0.5714285714285714
# average_precision: 0.2
# areaUnderROC: 0.76
#
# ************************************************************
#                      classification_report
# ************************************************************
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.52      0.68        25
#            1       0.20      1.00      0.33         3
#
#     accuracy                           0.57        28
#    macro avg       0.60      0.76      0.51        28
# weighted avg       0.91      0.57      0.65        28
#
# ************************************************************
#                      confusion_matrix
#
# ************************************************************
# array([[13, 12],
#        [ 0,  3]], dtype=int64)

# %%
model_1_stack = build_model_1(x_train_stack, y_train)
model_1_stack.best_score_
# Out:
# 0.6199999999999999

# %%
y_pred_prob_test_1_stack = model_1_stack.predict_proba(x_test_stack)[:,1]# 0 and 1 two clases
y_pred_int_test_1_stack = y_pred_prob_test_1_stack > Threshold
pd.Series(y_pred_int_test_1_stack).value_counts()
# Out:
# False    17
# True     11
# dtype: int64

# %%
metrics_summary(y_test_original, y_pred_int_test_1_stack)
# Out:
# accuracy: 0.7142857142857143
# average_precision: 0.2727272727272727
# areaUnderROC: 0.84
#
# ************************************************************
#                      classification_report
# ************************************************************
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.68      0.81        25
#            1       0.27      1.00      0.43         3
#
#     accuracy                           0.71        28
#    macro avg       0.64      0.84      0.62        28
# weighted avg       0.92      0.71      0.77        28
#
# ************************************************************
#                      confusion_matrix
#
# ************************************************************
# array([[17,  8],
#        [ 0,  3]], dtype=int64)

# %%
def data_meta(id, x, y, model):
    #get prediction from model 1
    pred_prob_meta = model.predict_proba(x)[:,1]
    pred_prob_meta = pd.Series(pred_prob_meta, 
                               index=x.index,
                               name=f'pred_{id}_meta')
    pred_int_meta = pred_prob_meta > Threshold
    y_meta = pd.Series(y & pred_int_meta, name=f'y_train_meta_{id}')
    x_meta = x.join(pred_int_meta)
    
    return x_meta, y_meta

# %%
x_train_meta_1, y_train_meta_1 = data_meta(1, x_train, y_train, model_1)
x_train_meta_1.shape, y_train_meta_1.shape
# Out:
# ((83, 35), (83,))

# %%
x_test_meta_1, y_test_meta_1 = data_meta(1, x_test_original, y_test_original, model_1)
x_test_meta_1.shape, y_test_meta_1.shape
# Out:
# ((28, 35), (28,))

# %%
x_train_meta_1_, x_cv_meta_1, y_train_meta_1_, y_cv_meta_1 = \
    train_test_split(x_train_meta_1, y_train_meta_1,
                    test_size=0.25,
                    stratify=y_train_meta_1,
                    random_state=2020)
#stratify mean samplling with the ratio of each class percentage in #all data.
x_train_meta_1_.shape, x_cv_meta_1.shape, y_train_meta_1_.shape,  y_cv_meta_1.shape
# Out:
# ((62, 35), (21, 35), (62,), (21,))

# %%
model_2_meta_1 = build_model_2(x_train_meta_1_, y_train_meta_1_, x_cv_meta_1, y_cv_meta_1)
y_pred_prob_test_2_meta_1 = model_2_meta_1.predict(x_test_meta_1)
y_pred_int_test_2_meta_1 = y_pred_prob_test_2_meta_1 > Threshold
pd.DataFrame(y_pred_int_test_2_meta_1).value_counts()
# Out:
# [LightGBM] [Warning] objective is set=binary, application=binary will be ignored. Current value: objective=binary
# [LightGBM] [Warning] objective is set=binary, application=binary will be ignored. Current value: objective=binary
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000201 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] objective is set=binary, application=binary will be ignored. Current value: objective=binary
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# True     14
# False    14
# dtype: int64

# %%
final_pred_2_meta_1 = y_pred_int_test_2_meta_1 &  y_pred_int_test_1
pd.DataFrame(final_pred_2_meta_1).value_counts()
# Out:
# False    15
# True     13
# dtype: int64

# %%
metrics_summary(y_test_original, final_pred_2_meta_1)
# Out:
# accuracy: 0.5
# average_precision: 0.09706959706959709
# areaUnderROC: 0.42666666666666664
#
# ************************************************************
#                      classification_report
# ************************************************************
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.52      0.65        25
#            1       0.08      0.33      0.12         3
#
#     accuracy                           0.50        28
#    macro avg       0.47      0.43      0.39        28
# weighted avg       0.78      0.50      0.59        28
#
# ************************************************************
#                      confusion_matrix
#
# ************************************************************
# array([[13, 12],
#        [ 2,  1]], dtype=int64)
