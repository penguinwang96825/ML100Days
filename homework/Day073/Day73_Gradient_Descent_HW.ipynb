# %% [markdown]
# # 作業重點
#
# 使用function y=(x+5)² 來練習學習率( leanrning rate ) 調整所造成的影響

# %% [markdown]
# # 作業目標:
#     請嘗試使用不同的組合驗證 learning rate 對所需 iteration 的影響
#     lr = [0.1, 0.0001]
#     主要驗證 Lr 對於grandient 收斂的速度

# %%
cur_x = 3
precision = 0.000001
max_iters = 10000
df = lambda x: 2*(x+5)

lr = 0.1
iters = 0
previous_step_size = 1 
iters_history = [iters]
x_history = [cur_x]

while previous_step_size > precision and iters < max_iters:
    prev_x = cur_x
    cur_x = cur_x - lr * df(prev_x)
    previous_step_size = abs(cur_x - prev_x)
    iters += 1
    print("Learning rate: {:.2f} | Iteration: {:3d} | X value: {:.4f}".format(lr, iters, cur_x))
    
    iters_history.append(iters)
    x_history.append(cur_x)
# Out:
# Learning rate: 0.10 | Iteration:   1 | X value: 1.4000
# Learning rate: 0.10 | Iteration:   2 | X value: 0.1200
# Learning rate: 0.10 | Iteration:   3 | X value: -0.9040
# Learning rate: 0.10 | Iteration:   4 | X value: -1.7232
# Learning rate: 0.10 | Iteration:   5 | X value: -2.3786
# Learning rate: 0.10 | Iteration:   6 | X value: -2.9028
# Learning rate: 0.10 | Iteration:   7 | X value: -3.3223
# Learning rate: 0.10 | Iteration:   8 | X value: -3.6578
# Learning rate: 0.10 | Iteration:   9 | X value: -3.9263
# Learning rate: 0.10 | Iteration:  10 | X value: -4.1410
# Learning rate: 0.10 | Iteration:  11 | X value: -4.3128
# Learning rate: 0.10 | Iteration:  12 | X value: -4.4502
# Learning rate: 0.10 | Iteration:  13 | X value: -4.5602
# Learning rate: 0.10 | Iteration:  14 | X value: -4.6482
# Learning rate: 0.10 | Iteration:  15 | X value: -4.7185
# Learning rate: 0.10 | Iteration:  16 | X value: -4.7748
# Learning rate: 0.10 | Iteration:  17 | X value: -4.8199
# ...

# %%
print("Totally iteations: ", iters)
print("The local minimum occurs at", cur_x)
# Out:
# Totally iteations:  66
# The local minimum occurs at -4.999996786123911

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

plt.figure(figsize=(15, 4))
plt.plot(iters_history, x_history)
plt.grid()
plt.show()

# %%
cur_x = 3
precision = 0.000001
max_iters = 10000
df = lambda x: 2*(x+5)

lr = 0.0001
iters = 0
previous_step_size = 1 
iters_history = [iters]
x_history = [cur_x]

while previous_step_size > precision and iters < max_iters:
    prev_x = cur_x
    cur_x = cur_x - lr * df(prev_x)
    previous_step_size = abs(cur_x - prev_x)
    iters += 1
    print("Learning rate: {:.4f} | Iteration: {:3d} | X value: {:.4f}".format(lr, iters, cur_x))
    
    iters_history.append(iters)
    x_history.append(cur_x)
# Out:
# Learning rate: 0.0001 | Iteration:   1 | X value: 2.9984
# Learning rate: 0.0001 | Iteration:   2 | X value: 2.9968
# Learning rate: 0.0001 | Iteration:   3 | X value: 2.9952
# Learning rate: 0.0001 | Iteration:   4 | X value: 2.9936
# Learning rate: 0.0001 | Iteration:   5 | X value: 2.9920
# Learning rate: 0.0001 | Iteration:   6 | X value: 2.9904
# Learning rate: 0.0001 | Iteration:   7 | X value: 2.9888
# Learning rate: 0.0001 | Iteration:   8 | X value: 2.9872
# Learning rate: 0.0001 | Iteration:   9 | X value: 2.9856
# Learning rate: 0.0001 | Iteration:  10 | X value: 2.9840
# Learning rate: 0.0001 | Iteration:  11 | X value: 2.9824
# Learning rate: 0.0001 | Iteration:  12 | X value: 2.9808
# Learning rate: 0.0001 | Iteration:  13 | X value: 2.9792
# Learning rate: 0.0001 | Iteration:  14 | X value: 2.9776
# Learning rate: 0.0001 | Iteration:  15 | X value: 2.9760
# Learning rate: 0.0001 | Iteration:  16 | X value: 2.9744
# ...

# %%
print("Totally iteations: ", iters)
print("The local minimum occurs at", cur_x)
# Out:
# Totally iteations:  10000
# The local minimum occurs at -3.917534277778167

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

plt.figure(figsize=(15, 4))
plt.plot(iters_history, x_history)
plt.grid()
plt.show()
