# %% [markdown]
# # 作業
#
# - 作業目標 : iris (dataset.load_iris()) 資料嘗試跑 kmeans (可以測試不同的群數 , init 等)

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn import datasets


np.random.seed(17)
# %matplotlib inline

# %%
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %% [markdown]
# ### 載入 相關套件 並 執行 kmean 實驗 ...
#
# - 實驗測試不同的群數
# - 實驗測試不同的初始值
# - 呈現結果

# %%
estimators = [('k_means_3', KMeans(n_clusters=3)), 
              ('k_means_3_bad_init', KMeans(n_clusters=3, n_init=1, init='random')), 
              ('k_means_4', KMeans(n_clusters=4)), 
              ('k_means_4_bad_init', KMeans(n_clusters=4, n_init=1, init='random'))]

# %%
titles = ['3 clusters', '3 clusters with bad initialization', '4 clusters', '4 clusters with bad initialization']
for i, (name, est) in enumerate(estimators):
    fig = plt.figure(i+1, figsize=(10, 4))
    ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
    
    ## Fit data
    est.fit(X)
    labels = est.labels_

    ax.scatter(X[:, 3], X[:, 0], X[:, 2],
               c=labels.astype(np.float), edgecolor='k')

    ax.w_xaxis.set_ticklabels([])
    ax.w_yaxis.set_ticklabels([])
    ax.w_zaxis.set_ticklabels([])
    ax.set_title(titles[i])
    ax.dist = 12
plt.show()
